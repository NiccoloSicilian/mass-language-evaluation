# %%
# only has vision encoder, no text transformer
from mass.modules.encoder import ImageEncoder
from mass.utils.io_utils import load_model_from_disk

zeroshot_encoder: ImageEncoder = load_model_from_disk(
    '../../resources/checkpoints/ViT-L-14/MNISTVal/nonlinear_zeroshot.pt', model_name='ViT-L-14'
)
# Out:
# 2025-09-07 22:36:41 INFO     Loading model from disk                                        ]8;id=399943;file:///media/donato/Extra-storage/Code/model-merging/mass/src/mass/utils/io_utils.py\mass.utils.io_utils]8;;\:]8;id=755979;file:///media/donato/Extra-storage/Code/model-merging/mass/src/mass/utils/io_utils.py#111\111]8;;\
#                              ../../resources/checkpoints/ViT-L-14/MNISTVal/nonlinear_zerosh
#                              ot.pt
#                     INFO     Loading ViT-L-14 pre-trained weights.                          ]8;id=703048;file:///media/donato/Extra-storage/Code/model-merging/mass/src/mass/modules/encoder.py\mass.modules.encoder]8;;\:]8;id=159397;file:///media/donato/Extra-storage/Code/model-merging/mass/src/mass/modules/encoder.py#21\21]8;;\
# ...

# %%
from mass.utils.io_utils import upload_model_to_hf

upload_model_to_hf(zeroshot_encoder, 'ViT-L-14', 'base')
# Out:
# pytorch_model.bin: 100%|██████████| 1.37G/1.37G [09:48<00:00, 2.33MB/s]
# ✅ Uploaded to https://huggingface.co/crisostomi/ViT-L-14-base
